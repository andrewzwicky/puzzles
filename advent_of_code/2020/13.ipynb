# %%
# %load_ext autoreload
# %autoreload 2

# %%
import requests
from session import SESSION
from common import print_problem, get_problem_input, submit_answer
from bs4 import BeautifulSoup
from IPython.core.display import HTML
from collections import Counter
import re
from collections import defaultdict
from copy import copy, deepcopy
import itertools

# %%
DAY = 13

# %%
raw_data, data = get_problem_input(DAY)
# Out:
# Raw Data:
# '1002578\n19,x,x,x,x,x,x,x,x,x,x,x,x,37,x,x,x,x,x,751,x,29,x,x,x,x,x,x,x,x,x,x,13,'
# Split Data:
# ['1002578',
#  '19,x,x,x,x,x,x,x,x,x,x,x,x,37,x,x,x,x,x,751,x,29,x,x,x,x,x,x,x,x,x,x,13,x,x,x,x,x,x,x,x,x,23,x,x,x,x,x,x,x,431,x,x,x,x,x,x,x,x,x,41,x,x,x,x,x,x,17']

# %%
data[0]
# Out:
# '1002578'

# %%
data[1]
# Out:
# '19,x,x,x,x,x,x,x,x,x,x,x,x,37,x,x,x,x,x,751,x,29,x,x,x,x,x,x,x,x,x,x,13,x,x,x,x,x,x,x,x,x,23,x,x,x,x,x,x,x,431,x,x,x,x,x,x,x,x,x,41,x,x,x,x,x,x,17'

# %%
def func(ts, times):
    result = 0
    ts = int(ts)
    inttimes = [int(x) for x in times.split(',') if x != 'x']
    print(inttimes)
    
    res = None
    bus = None
    
    for i in inttimes:
        rem = (((ts // i) * i) + i) - ts
        print(ts,i,rem)
        if res is None or rem < res:
            res = rem
            bus = i
    print(res, bus)
    
    result = bus * res
    print(result)
    return result

# %%
func('939', '7,13,59,31,19')
# Out:
# [7, 13, 59, 31, 19]
# 939 7 6
# 939 13 10
# 939 59 5
# 939 31 22
# 939 19 11
# 5 59
# 295
# 295

# %%
first = func(*data)
# Out:
# [19, 37, 751, 29, 13, 23, 431, 41, 17]
# 1002578 19 14
# 1002578 37 11
# 1002578 751 7
# 1002578 29 10
# 1002578 13 8
# 1002578 23 15
# 1002578 431 359
# 1002578 41 36
# 1002578 17 14
# 7 751
# 5257

# %%
submit_answer(DAY, 1, first)
# Out:
# 5257
# ("That's the right answer!  You are one gold star closer to saving your "
#  'vacation. [Continue to Part Two]')
# True

# %%
def generator(mult, s):
    for n in itertools.count(start=1):
        yield (n * mult) - s

# %%
x= generator(10,2)

# %%
next(x)
# Out:
# 88

# %%
def func2(times):
    result = 0
    
    inttimes = [int(x) if x != 'x' else None for x in times.split(',') ]
    #print(inttimes)
    
    times = dict()
    subs = dict()
    highest = 0
    current = Counter()
    gens = dict()
    
    for i,n in enumerate(inttimes):
        if n:
            times[n] = i
            subs[n] = (n-i) % n
            highest = max(highest,n)
            gens[n] = generator(n, n-i)
            current[n] = next(gens[n])

#     print(gens)
#     print(current)
#     print(current.most_common()[-1])

    
    
    
    
#     #print(times)
#     #print(subs)    
#     #print(multiple)
    
#     gens = [create_generator]
    
#     for n in itertools.count(start=1):
#         found=True
#         x = (n * highest) - times[highest]
# #         if  1_069_000 > x > 1_068_000:
# # #            print(n, n* highest, n-subs[highest])
# #             print(x)
#         for k,v in subs.items():            
#             if x % k != v:
#                 found=False
#                 break
        
# #         if x > 1_070_000:
# #             raise ValueError
#         if found:
#             break
    
    print(x)
    return x

# %%
second = func2('7,13,x,x,59,x,31,19')
# Out:
# 7 Counter({7: 7, 19: 7, 31: 6, 59: 4, 13: 1})
# 13 Counter({13: 14, 7: 7, 19: 7, 31: 6, 59: 4})
# 59 Counter({59: 63, 13: 14, 7: 7, 19: 7, 31: 6})
# 31 Counter({59: 63, 31: 37, 13: 14, 7: 7, 19: 7})
# 19 Counter({59: 63, 31: 37, 19: 26, 13: 14, 7: 7})
# 7 Counter({59: 63, 31: 37, 19: 26, 7: 14, 13: 14})
# 13 Counter({59: 63, 31: 37, 13: 27, 19: 26, 7: 14})
# 7 Counter({59: 63, 31: 37, 13: 27, 19: 26, 7: 21})
# 7 Counter({59: 63, 31: 37, 7: 28, 13: 27, 19: 26})
# 19 Counter({59: 63, 19: 45, 31: 37, 7: 28, 13: 27})
# 13 Counter({59: 63, 19: 45, 13: 40, 31: 37, 7: 28})
# 7 Counter({59: 63, 19: 45, 13: 40, 31: 37, 7: 35})
# 7 Counter({59: 63, 19: 45, 7: 42, 13: 40, 31: 37})
# 31 Counter({31: 68, 59: 63, 19: 45, 7: 42, 13: 40})
# 13 Counter({31: 68, 59: 63, 13: 53, 19: 45, 7: 42})
# 7 Counter({31: 68, 59: 63, 13: 53, 7: 49, 19: 45})
# 19 Counter({31: 68, 19: 64, 59: 63, 13: 53, 7: 49})
# 7 Counter({31: 68, 19: 64, 59: 63, 7: 56, 13: 53})
# ...

# %%
second = func2(data[1])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-126-659978f22336> in <module>
# ----> 1 second = func2(data[1])
#
# <ipython-input-124-c7ea93abd7be> in func2(times)
#      25 # #            print(n, n* highest, n-subs[highest])
#      26 #             print(x)
# ---> 27         for k,v in subs.items():
#      28             if x % k != v:
#      29                 found=False
#
# KeyboardInterrupt:

# %%
submit_answer(DAY, 2, second)
